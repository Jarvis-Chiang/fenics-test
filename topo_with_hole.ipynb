# %%
# !conda list dolfin
# !conda list mshr

# %%
from dolfin import *
import numpy as np
# import pygad
import pyswarms as ps
import matplotlib.pyplot as plt
import mshr as mr

set_log_level(50)

# %%
# 创建网格
rectangle = mr.Rectangle(Point(0.0, 0.0), Point(9.0, 6.0))
circle1 = mr.Circle(Point(2.5, 3.0), 1.5)
circle2 = mr.Circle(Point(6.5, 3.0), 1.5)
domain = rectangle - circle1 - circle2  

# 创建网格
mymesh = mr.generate_mesh(domain, 32)
vertex_num = mymesh.num_vertices()
cell_num = mymesh.num_cells()
plot(mymesh)
print(f"vertex number: {vertex_num}")
print(f"cell number: {cell_num}")
# Out:
# vertex number: 1161
# cell number: 2096

# %%
# 初始化
"""初始化"""
# 二维正交各向异性
E1, E2, mu12, G12 = 130000, 7700, 0.33, 4800
# 转动角度
Theta = 0
Theta_init = 5
# 载荷
forcing = Constant((500, 0))

# 弹性张量
C2D_Iso = np.array([
    [E1/(1-mu12**2),        mu12*E2/(1-mu12**2),         0  ],
    [mu12*E2/(1-mu12**2),   E2/(1-mu12**2),              0  ],
    [0,                     0,                           G12]
])

# 转轴公式
def T2D_inv(theta):
    theta = theta * np.pi / 180.0
    c = cos(theta)
    s = sin(theta)
    Trans = np.array([
        [c**2,  s**2,   -2*s*c],
        [s**2,  c**2,   2*s*c],
        [s*c,   -s*c,   c**2 - s**2]
    ])
    return Trans

# 准备网格
V = VectorFunctionSpace(mymesh, "CG", 1)
T = FunctionSpace(mymesh, "DG", 0)
u_sol = Function(V)
Theta_sol = Function(T)
u_trial = TrialFunction(V)
v_test = TestFunction(V)

# %%
# 定义物理方程
# 物理方程
def epsilon(u):
    engineering_strain = 0.5 * (nabla_grad(u) + nabla_grad(u).T)
    return engineering_strain

# 本构方程
def sigma_tensor(u, Theta_Ev):
    # 计算应变张量
    epsilon_ij = epsilon(u)
    ep = as_vector([epsilon_ij[0,0], epsilon_ij[1,1], epsilon_ij[0,1]])
    # 使用弹性系数计算应力张量
    Q_bar = np.dot(np.dot(T2D_inv(Theta_Ev), C2D_Iso), T2D_inv(Theta_Ev).T)
    sigma_ij = np.dot(Q_bar, ep)

    return as_tensor([[sigma_ij[0], sigma_ij[2]],
                      [sigma_ij[2], sigma_ij[1]]])

# 弹性能密度
def psi(u, Theta):
    return 0.5 * inner(sigma_tensor(u, Theta), epsilon(u))

# %%
# 定义边界
# 狄利克雷边界
def clamped_boundary(x, on_boundary):
    return on_boundary and x[0] < DOLFIN_EPS
bc = DirichletBC(V, Constant((0.0, 0.0)), clamped_boundary)

# 自然边界
class RightEnd(SubDomain):
    def inside(self, x, on_boundary):
        return on_boundary and abs(x[0] - 9) < DOLFIN_EPS 
right_end_boundary = RightEnd()

boundary_mark = MeshFunction("size_t", mymesh, mymesh.topology().dim()-1)
boundary_mark.set_all(0)
right_end_boundary.mark(boundary_mark, 1)

# %%
# 有限元求解
def FEA(lhs, rhs, u:Function, bc:DirichletBC) -> Function: 
    problem = LinearVariationalProblem(lhs, rhs, u, bc)
    solver = LinearVariationalSolver(problem)
    return solver.solve()

# %%
# 有限元计算
theta = 0 * np.ones(T.dim())
theta_init = Function(T)
theta_init.vector()[:] = theta
lhs = inner(sigma_tensor(u_trial, theta_init), nabla_grad(v_test)) * dx
rhs = dot(forcing, v_test) * ds(subdomain_data=boundary_mark, domain=mymesh, subdomain_id=1)
FEA(lhs, rhs, u_sol ,bc=[bc])
plot(u_sol, title="deformation U")

# %%
# 计算最大主应力场
stress = sigma_tensor(u_sol, theta_init)
# 创建一个张量函数空间来存储应力场
V_ten = TensorFunctionSpace(mymesh, 'CG', 1)
stress_func = Function(V_ten)

stress_func.assign(project(stress, V_ten))

# 定义函数空间
V_max_principal = FunctionSpace(mymesh, 'CG', 1)
V_vec = VectorFunctionSpace(mymesh, 'CG', 1)

# 定义最大主应力函数和方向函数
max_principal_stress = Function(V_max_principal)
max_principal_direction = Function(V_vec)

# 提取应力值
stress_values = stress_func.vector().get_local().reshape((-1, 2, 2))

# 获取本地向量大小
local_size_stress = max_principal_stress.vector().local_size()
local_size_direction = max_principal_direction.vector().local_size()

# 初始化最大主应力和方向数组
max_principal_stress_values = np.zeros(local_size_stress)
max_principal_direction_values = np.zeros((local_size_direction // 2, 2))  # 确保方向是2维

# 计算最大主应力和方向
for i, stress_tensor in enumerate(stress_values):
    # 计算特征值和特征向量
    eigenvalues, eigenvectors = np.linalg.eig(stress_tensor)
    max_index = np.argmax(eigenvalues)
    max_principal_stress_values[i] = eigenvalues[max_index]
    max_principal_direction_values[i] = eigenvectors[:, max_index]

# 将最大主应力值和方向赋值给相应的函数
max_principal_stress.vector().set_local(max_principal_stress_values)
max_principal_direction.vector().set_local(max_principal_direction_values.flatten())

# 打印最大主应力值和方向
print("Max Principal Stress Values:", max_principal_stress.vector().get_local())
print("Max Principal Direction Values:", max_principal_direction.vector().get_local())
plot(max_principal_direction)
# Out:
# Max Principal Stress Values: [504.31530244 458.42540811 491.18898672 ... 963.60850254 780.38192392
#  805.67351115]
# Max Principal Direction Values: [ 0.99975121 -0.02230516  0.99945965 ... -0.02552347  0.99973948
#  -0.02282472]

# %%
# 计算拉应力场和压应力场
stress = sigma_tensor(u_sol, theta_init)

# 创建一个张量函数空间来存储应力场
V_ten = TensorFunctionSpace(mymesh, 'CG', 1)
stress_func = Function(V_ten)

stress_func.assign(project(stress, V_ten))

# 定义函数空间
V_scalar = FunctionSpace(mymesh, 'CG', 1)
V_vec = VectorFunctionSpace(mymesh, 'CG', 1)

# 定义拉应力和压应力函数及其方向函数
tensile_stress = Function(V_scalar)
compressive_stress = Function(V_scalar)
tensile_direction = Function(V_vec)
compressive_direction = Function(V_vec)

# 提取应力值
stress_values = stress_func.vector().get_local().reshape((-1, 2, 2))

# 获取本地向量大小
local_size_stress = tensile_stress.vector().local_size()
local_size_direction = tensile_direction.vector().local_size()

# 初始化拉应力和压应力及其方向数组
tensile_stress_values = np.zeros(local_size_stress)
compressive_stress_values = np.zeros(local_size_stress)
tensile_direction_values = np.zeros((local_size_direction // 2, 2))  # 确保方向是2维
compressive_direction_values = np.zeros((local_size_direction // 2, 2))  # 确保方向是2维

# 计算拉应力和压应力及其方向
for i, stress_tensor in enumerate(stress_values):
    # 计算特征值和特征向量
    eigenvalues, eigenvectors = np.linalg.eig(stress_tensor)
    
    # 分别获取拉应力和压应力及其方向
    tensile_eigenvalues = eigenvalues[eigenvalues > 0]
    compressive_eigenvalues = eigenvalues[eigenvalues < 0]
    
    if len(tensile_eigenvalues) > 0:
        max_tensile_index = np.argmax(tensile_eigenvalues)
        tensile_stress_values[i] = tensile_eigenvalues[max_tensile_index]
        tensile_direction_values[i] = eigenvectors[:, eigenvalues == tensile_eigenvalues[max_tensile_index]].flatten()
    else:
        tensile_stress_values[i] = 0
        tensile_direction_values[i] = [0, 0]
    
    if len(compressive_eigenvalues) > 0:
        max_compressive_index = np.argmin(compressive_eigenvalues)
        compressive_stress_values[i] = compressive_eigenvalues[max_compressive_index]
        compressive_direction_values[i] = eigenvectors[:, eigenvalues == compressive_eigenvalues[max_compressive_index]].flatten()
    else:
        compressive_stress_values[i] = 0
        compressive_direction_values[i] = [0, 0]

# 将拉应力和压应力值及其方向赋值给相应的函数
tensile_stress.vector().set_local(tensile_stress_values)
compressive_stress.vector().set_local(compressive_stress_values)
tensile_direction.vector().set_local(tensile_direction_values.flatten())
compressive_direction.vector().set_local(compressive_direction_values.flatten())

# 绘制拉应力方向场
plot(tensile_direction)
# 绘制压应力方向场
# plot(compressive_direction)

# %%
# 可视化
def plot_theta_vector(theta:Function, mesh, scale=30, width=0.001, title="Vector field"):
    theta_rad = np.deg2rad(Theta_sol.vector()[:])  # 将角度转换为弧度
    x_values = np.cos(theta_rad)
    y_values = np.sin(theta_rad)
    # 将二维向量表示合并为一个二维数组
    vector_values = np.vstack((x_values, y_values)).T  # 转置使每行是一个向量
    # 获取网格的中心点
    cell_midpoints = [cell.midpoint() for cell in cells(mesh)]
    # 提取中心点的坐标
    x_coords = np.array([p.x() for p in cell_midpoints])
    y_coords = np.array([p.y() for p in cell_midpoints])
    u = vector_values[:, 0]
    v = vector_values[:, 1]
    # 可视化向量场
    plt.figure()
    # plot(mesh)
    # plt.quiver(x_coords, y_coords, u, v)
    # 绘制正方向的箭头
    plt.quiver(x_coords, y_coords, u, v, angles='xy', scale_units='xy', scale=scale, width=width, color='b')
    # 绘制反方向的箭头
    plt.quiver(x_coords, y_coords, -u, -v, angles='xy', scale_units='xy', scale=scale, width=width, color='b')

    plt.title(title)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.axis("equal")
    plt.show()

# %%
# 定义计算总能量的函数
def compute_total_energy(theta_values):
    theta_func = Function(T)
    theta_func.vector()[:] = theta_values
    Theta_sol.assign(theta_func)

    # 定义问题
    lhs = inner(sigma_tensor(u_trial, Theta_sol), nabla_grad(v_test)) * dx
    rhs = dot(forcing, v_test) * ds(subdomain_data=boundary_mark, domain=mymesh, subdomain_id=1)
    
    # 求解
    FEA(lhs, rhs, u_sol, bc)
    
    # 计算总能量
    energy_density = psi(u_sol, Theta_sol) * dx
    total_energy = assemble(energy_density)
    
    return total_energy

def compute_energy_derivative(theta_values:np.array):
    theta_func = Function(T)
    theta_func.vector()[:] = theta_values
    Theta_sol.assign(theta_func)

    # 定义问题
    lhs = inner(sigma_tensor(u_trial, Theta_sol), nabla_grad(v_test)) * dx
    rhs = dot(forcing, v_test) * ds(subdomain_data=boundary_mark, domain=mymesh, subdomain_id=1)
    
    # 求解
    FEA(lhs, rhs, u_sol, bc)
    
    # 计算总能量
    energy_density = psi(u_sol, Theta_sol) * dx
    
    # 计算能量密度对theta的导数
    d_energy_dtheta = derivative(energy_density, Theta_sol, TestFunction(T))
    
    # 将其作为函数输出
    d_energy_dtheta_func = Function(T)
    assemble(d_energy_dtheta, tensor=d_energy_dtheta_func.vector())
    
    return d_energy_dtheta_func.vector().get_local()

# %%
import numpy as np

# Adam优化器实现
def adam_optimizer(theta_init, objective, gradient, learning_rate=-0.1, beta1=0.9, beta2=0.999, epsilon=1e-8, max_iters=5000):
    theta = np.copy(theta_init)
    m = np.zeros_like(theta)
    v = np.zeros_like(theta)
    t = 0
    energy_history = []

    for i in range(max_iters):
        t += 1
        g = gradient(theta)
        m = beta1 * m + (1 - beta1) * g
        v = beta2 * v + (1 - beta2) * (g ** 2)
        m_hat = m / (1 - beta1 ** t)
        v_hat = v / (1 - beta2 ** t)
        
        theta -= learning_rate * m_hat / (np.sqrt(v_hat) + epsilon)

        energy = objective(theta)
        energy_history.append(energy)

        if i % 100 == 0:
            print(f"Iteration {i}, Energy: {objective(theta)}")
    
    return theta, energy_history

# 使用Adam优化器最小化能量
theta_init = 0 * np.ones(T.dim())
optimized_theta, energy_history = adam_optimizer(theta_init, 
                                                 objective=compute_total_energy, 
                                                 gradient=compute_energy_derivative, 
                                                 learning_rate=-0.1, 
                                                 max_iters=10000)

# 输出最终结果
print("Optimized Theta Values:", optimized_theta)

# 可视化优化后的theta
theta_function = Function(T)
theta_function.vector()[:] = optimized_theta
# plot_theta_vector(theta_function)
# Out:
# Iteration 0, Energy: 226.69330045681662
# Iteration 100, Energy: 156.8781388013455
# Iteration 200, Energy: 133.01416985386828
# Iteration 300, Energy: 122.90995888783074
# Iteration 400, Energy: 118.61761193055955
# Iteration 500, Energy: 116.81411775584813
# Iteration 600, Energy: 115.75023262214923
# Iteration 700, Energy: 114.72972267760211
# Iteration 800, Energy: 113.74332579793135
# Iteration 900, Energy: 113.16290305017327
# Iteration 1000, Energy: 112.4194427642163
# Iteration 1100, Energy: 111.5281415809408
# Iteration 1200, Energy: 109.81425650732811
# Iteration 1300, Energy: 109.24860883926631
# Iteration 1400, Energy: 108.94328752879171
# Iteration 1500, Energy: 108.73770616874029
# Iteration 1600, Energy: 108.55868791274956
# Iteration 1700, Energy: 108.43089249798534
# Iteration 1800, Energy: 108.32933004535423
# Iteration 1900, Energy: 108.24647439856689
# Iteration 2000, Energy: 108.20258694959969
# Iteration 2100, Energy: 108.18949346935221
# Iteration 2200, Energy: 108.18286595642087
# Iteration 2300, Energy: 108.17862123158056
# Iteration 2400, Energy: 108.17700316374585
# Iteration 2500, Energy: 108.17657279319721
# Iteration 2600, Energy: 108.17657464971856
# Iteration 2700, Energy: 108.17675398567192
# Iteration 2800, Energy: 108.17713040177401
# Iteration 2900, Energy: 108.1777663551225
# Iteration 3000, Energy: 108.17877260974579
# Iteration 3100, Energy: 108.18033086827494
# Iteration 3200, Energy: 108.18242204162101
# Iteration 3300, Energy: 108.18410574385997
# Iteration 3400, Energy: 108.18350789469034
# Iteration 3500, Energy: 108.17829925346737
# Iteration 3600, Energy: 108.13586203092673
# Iteration 3700, Energy: 108.00224401795934
# Iteration 3800, Energy: 108.00321517857724
# Iteration 3900, Energy: 108.00253201092264
# Iteration 4000, Energy: 108.00101134055356
# Iteration 4100, Energy: 107.99995804541237
# Iteration 4200, Energy: 107.99517027275314
# Iteration 4300, Energy: 107.9915954126885
# Iteration 4400, Energy: 107.99158566965707
# Iteration 4500, Energy: 107.99197062263424
# Iteration 4600, Energy: 107.99254100563952
# Iteration 4700, Energy: 107.99323586129874
# Iteration 4800, Energy: 107.99287230288004
# Iteration 4900, Energy: 107.99055417047336
# Iteration 5000, Energy: 107.99038258792872
# Iteration 5100, Energy: 107.99056229996282
# Iteration 5200, Energy: 107.99059316425915
# Iteration 5300, Energy: 107.99059542702167
# Iteration 5400, Energy: 107.99056686897183
# Iteration 5500, Energy: 107.99051410629714
# Iteration 5600, Energy: 107.99042835197355
# Iteration 5700, Energy: 107.99031265385969
# Iteration 5800, Energy: 107.99017899221843
# Iteration 5900, Energy: 107.99005674878374
# Iteration 6000, Energy: 107.98998018059989
# Iteration 6100, Energy: 107.98995855586443
# Iteration 6200, Energy: 107.98994004558332
# Iteration 6300, Energy: 107.98995536414645
# Iteration 6400, Energy: 107.98997731072846
# Iteration 6500, Energy: 107.98999373675672
# Iteration 6600, Energy: 107.9900115764006
# Iteration 6700, Energy: 107.9900274163716
# Iteration 6800, Energy: 107.9900436596533
# Iteration 6900, Energy: 107.99006355947226
# Iteration 7000, Energy: 107.99007019972923
# Iteration 7100, Energy: 107.99007693629464
# Iteration 7200, Energy: 107.99008439451158
# Iteration 7300, Energy: 107.99010285215849
# Iteration 7400, Energy: 107.99011423210128
# Iteration 7500, Energy: 107.99012871766956
# Iteration 7600, Energy: 107.99015117163026
# Iteration 7700, Energy: 107.9901757803775
# Iteration 7800, Energy: 107.99022009284008
# Iteration 7900, Energy: 107.99029927844057
# Iteration 8000, Energy: 107.9904323724829
# Iteration 8100, Energy: 107.99078427298505
# Iteration 8200, Energy: 107.99105730203611
# Iteration 8300, Energy: 107.99117321698574
# Iteration 8400, Energy: 107.99123458512673
# Iteration 8500, Energy: 107.99121646844799
# Iteration 8600, Energy: 107.99117448663024
# Iteration 8700, Energy: 107.99128465431717
# Iteration 8800, Energy: 107.99116992563961
# Iteration 8900, Energy: 107.9912053999485
# Iteration 9000, Energy: 107.99118969263941
# Iteration 9100, Energy: 107.99117029960506
# Iteration 9200, Energy: 107.99124064440345
# Iteration 9300, Energy: 107.99122469047217
# Iteration 9400, Energy: 107.99116840542541
# Iteration 9500, Energy: 107.99117345422782
# Iteration 9600, Energy: 107.99115546124699
# Iteration 9700, Energy: 107.99121542612065
# Iteration 9800, Energy: 107.99125390761444
# Iteration 9900, Energy: 107.99132037704474
# Optimized Theta Values: [12.32593138  4.58595698  5.11850026 ... 22.48749123 -6.96424842
#  -4.57704853]

# %%
plt.plot(energy_history)
import save_data
save_data.save_vector_field_to_txt(mymesh, theta_function, filename="output/theta_vector(adam).txt")
# Out:
# File 'output/theta_vector(adam).txt' created successfully.

# %%
plot_theta_vector(theta_function, mesh=mymesh, scale=12, width=0.0018, title="Vector field(Adam)")

# %%
import numpy as np
import matplotlib.pyplot as plt

# SGD优化器实现（带有小批量）
def sgd_optimizer(theta_init, objective, gradient, learning_rate=-0.1, max_iters=1000, batch_size=10):
    theta = np.copy(theta_init)
    energy_history = []
    num_elements = len(theta)

    for i in range(max_iters):
        # 随机选择一个小批量
        indices = np.random.choice(num_elements, batch_size, replace=False)
        
        # 计算当前小批量的梯度
        g = gradient(theta)
        g_batch = np.zeros_like(theta)
        g_batch[indices] = g[indices]
        
        # 更新参数
        theta -= learning_rate * g_batch
        
        # 计算当前的总能量
        energy = objective(theta)
        energy_history.append(energy)
        
        if i % 100 == 0:
            print(f"Iteration {i}, Energy: {energy}")
    
    return theta, energy_history

# 使用SGD优化器最小化能量
theta_init = 0 * np.ones(T.dim())
optimized_theta, energy_history = sgd_optimizer(theta_init,
                                                objective=compute_total_energy,
                                                gradient=compute_energy_derivative, 
                                                learning_rate=-2, 
                                                max_iters=50000, 
                                                batch_size=200)

# 输出最终结果
print("Optimized Theta Values:", optimized_theta)
# Out:
# Iteration 0, Energy: 227.76718762471353
# Iteration 100, Energy: 219.46730844940888
# Iteration 200, Energy: 213.85823074779893
# Iteration 300, Energy: 208.08508153086106
# Iteration 400, Energy: 203.31340860623968
# Iteration 500, Energy: 198.57206374920784
# Iteration 600, Energy: 194.65499479270167
# Iteration 700, Energy: 190.78168422193713
# Iteration 800, Energy: 187.4942418399477
# Iteration 900, Energy: 184.52999443650413
# Iteration 1000, Energy: 182.09128411065186
# Iteration 1100, Energy: 179.59153184218968
# Iteration 1200, Energy: 177.11199425510046
# Iteration 1300, Energy: 174.95322122015764
# Iteration 1400, Energy: 172.86236017659513
# Iteration 1500, Energy: 170.9690273367473
# Iteration 1600, Energy: 169.2887840372731
# Iteration 1700, Energy: 167.63914514082262
# Iteration 1800, Energy: 166.02456908915482
# Iteration 1900, Energy: 164.66419031966456
# Iteration 2000, Energy: 163.4152215608703
# Iteration 2100, Energy: 162.0812308582002
# Iteration 2200, Energy: 160.88785737412644
# Iteration 2300, Energy: 159.75666204027203
# Iteration 2400, Energy: 158.69489759287748
# Iteration 2500, Energy: 157.74602403949652
# Iteration 2600, Energy: 156.7649430085838
# Iteration 2700, Energy: 155.85754163223967
# Iteration 2800, Energy: 155.03287851733344
# Iteration 2900, Energy: 154.21911269278357
# Iteration 3000, Energy: 153.45645246151997
# Iteration 3100, Energy: 152.71623266187447
# Iteration 3200, Energy: 151.98260783967166
# Iteration 3300, Energy: 151.29872459659154
# Iteration 3400, Energy: 150.63885803395226
# Iteration 3500, Energy: 150.0098371861785
# Iteration 3600, Energy: 149.40743647658965
# Iteration 3700, Energy: 148.79297001687635
# Iteration 3800, Energy: 148.22574037793567
# Iteration 3900, Energy: 147.70362935759997
# Iteration 4000, Energy: 147.17217721762853
# Iteration 4100, Energy: 146.65372318165296
# Iteration 4200, Energy: 146.1771695599382
# Iteration 4300, Energy: 145.7068668122078
# Iteration 4400, Energy: 145.26131516221673
# Iteration 4500, Energy: 144.80988771818315
# Iteration 4600, Energy: 144.39512006468556
# Iteration 4700, Energy: 143.99422677207664
# Iteration 4800, Energy: 143.5816277152689
# Iteration 4900, Energy: 143.16806936839475
# Iteration 5000, Energy: 142.78456228961824
# Iteration 5100, Energy: 142.40848681263685
# Iteration 5200, Energy: 142.0491716293059
# Iteration 5300, Energy: 141.69435011137162
# Iteration 5400, Energy: 141.3418813517522
# Iteration 5500, Energy: 140.9915486478971
# Iteration 5600, Energy: 140.67612408588522
# Iteration 5700, Energy: 140.36055439769387
# Iteration 5800, Energy: 140.05007152379645
# Iteration 5900, Energy: 139.76738553486442
# Iteration 6000, Energy: 139.48044346186614
# Iteration 6100, Energy: 139.2009583978414
# Iteration 6200, Energy: 138.9234691408811
# Iteration 6300, Energy: 138.65676516589227
# Iteration 6400, Energy: 138.40736357066973
# Iteration 6500, Energy: 138.16362471668245
# Iteration 6600, Energy: 137.91691487569977
# Iteration 6700, Energy: 137.68996610700384
# Iteration 6800, Energy: 137.45723563882447
# Iteration 6900, Energy: 137.22468143953336
# Iteration 7000, Energy: 136.99443935175213
# Iteration 7100, Energy: 136.7710139217219
# Iteration 7200, Energy: 136.5537340759185
# Iteration 7300, Energy: 136.34349005179638
# Iteration 7400, Energy: 136.14357998948515
# Iteration 7500, Energy: 135.94499098646378
# Iteration 7600, Energy: 135.74187999075346
# Iteration 7700, Energy: 135.55612551309005
# Iteration 7800, Energy: 135.36904912141011
# Iteration 7900, Energy: 135.18253320183925
# Iteration 8000, Energy: 134.99760093866104
# Iteration 8100, Energy: 134.827112883055
# Iteration 8200, Energy: 134.65564698187453
# Iteration 8300, Energy: 134.49131812697246
# Iteration 8400, Energy: 134.3200149703528
# Iteration 8500, Energy: 134.15433160564749
# Iteration 8600, Energy: 133.99695253983145
# Iteration 8700, Energy: 133.83671722106402
# Iteration 8800, Energy: 133.68418583432475
# Iteration 8900, Energy: 133.53900560629882
# Iteration 9000, Energy: 133.38484186996186
# Iteration 9100, Energy: 133.24189109640665
# Iteration 9200, Energy: 133.10299533407164
# Iteration 9300, Energy: 132.96554154452002
# Iteration 9400, Energy: 132.82884693251629
# Iteration 9500, Energy: 132.6956731645597
# Iteration 9600, Energy: 132.56263002432354
# Iteration 9700, Energy: 132.43534307372371
# Iteration 9800, Energy: 132.31446230166307
# Iteration 9900, Energy: 132.19628500020656
# Iteration 10000, Energy: 132.07409823100136
# Iteration 10100, Energy: 131.95567330332943
# Iteration 10200, Energy: 131.8373227586005
# Iteration 10300, Energy: 131.72712962524733
# Iteration 10400, Energy: 131.6168606366511
# Iteration 10500, Energy: 131.50533432481123
# Iteration 10600, Energy: 131.3985209033275
# Iteration 10700, Energy: 131.2931048254915
# Iteration 10800, Energy: 131.19111200252294
# Iteration 10900, Energy: 131.08976666976994
# Iteration 11000, Energy: 130.99093221177043
# Iteration 11100, Energy: 130.8869973754185
# Iteration 11200, Energy: 130.7904222905175
# Iteration 11300, Energy: 130.6944012811944
# Iteration 11400, Energy: 130.59907686156401
# Iteration 11500, Energy: 130.5034148486238
# Iteration 11600, Energy: 130.41450141410144
# Iteration 11700, Energy: 130.32864307580542
# Iteration 11800, Energy: 130.24330164958621
# Iteration 11900, Energy: 130.15351138463845
# Iteration 12000, Energy: 130.07074363066113
# Iteration 12100, Energy: 129.98540972033408
# Iteration 12200, Energy: 129.9045543725682
# Iteration 12300, Energy: 129.82367998466256
# Iteration 12400, Energy: 129.74327846384782
# Iteration 12500, Energy: 129.6669698101079
# Iteration 12600, Energy: 129.59040263053987
# Iteration 12700, Energy: 129.5121644096589
# Iteration 12800, Energy: 129.43533173897333
# Iteration 12900, Energy: 129.35981766667086
# Iteration 13000, Energy: 129.28838347167928
# Iteration 13100, Energy: 129.21649680201924
# Iteration 13200, Energy: 129.14809583941727
# Iteration 13300, Energy: 129.07666341197466
# Iteration 13400, Energy: 129.0095595457579
# Iteration 13500, Energy: 128.94253656668664
# Iteration 13600, Energy: 128.8742975159476
# Iteration 13700, Energy: 128.80465392684007
# Iteration 13800, Energy: 128.73647393865812
# Iteration 13900, Energy: 128.6744193677233
# Iteration 14000, Energy: 128.61233945752426
# Iteration 14100, Energy: 128.54993498500417
# Iteration 14200, Energy: 128.4889318915269
# Iteration 14300, Energy: 128.4264373996731
# Iteration 14400, Energy: 128.36721254782674
# Iteration 14500, Energy: 128.3067619350801
# Iteration 14600, Energy: 128.24991042240381
# Iteration 14700, Energy: 128.18921760474075
# Iteration 14800, Energy: 128.1309780967945
# Iteration 14900, Energy: 128.0701833602038
# Iteration 15000, Energy: 128.01391160081644
# Iteration 15100, Energy: 127.95772868109955
# Iteration 15200, Energy: 127.90288214935576
# Iteration 15300, Energy: 127.84680778493679
# Iteration 15400, Energy: 127.79182500707746
# Iteration 15500, Energy: 127.73810406017245
# Iteration 15600, Energy: 127.68310940546348
# Iteration 15700, Energy: 127.62951537007459
# Iteration 15800, Energy: 127.57607728636405
# Iteration 15900, Energy: 127.52476061977369
# Iteration 16000, Energy: 127.47256784785523
# Iteration 16100, Energy: 127.42279866486369
# Iteration 16200, Energy: 127.37010636740658
# Iteration 16300, Energy: 127.3199278810166
# Iteration 16400, Energy: 127.26898827128063
# Iteration 16500, Energy: 127.21895470755813
# Iteration 16600, Energy: 127.16869305445286
# Iteration 16700, Energy: 127.11922690493043
# Iteration 16800, Energy: 127.07434159909894
# Iteration 16900, Energy: 127.02473899023833
# Iteration 17000, Energy: 126.97700896706921
# Iteration 17100, Energy: 126.93187281706675
# Iteration 17200, Energy: 126.88203749661426
# Iteration 17300, Energy: 126.83358639618719
# Iteration 17400, Energy: 126.78742301939415
# Iteration 17500, Energy: 126.74202308180277
# Iteration 17600, Energy: 126.6971888067842
# Iteration 17700, Energy: 126.6528433659988
# Iteration 17800, Energy: 126.6093394721543
# Iteration 17900, Energy: 126.56557031942214
# Iteration 18000, Energy: 126.52142689302423
# Iteration 18100, Energy: 126.47899639563829
# Iteration 18200, Energy: 126.43490572919701
# Iteration 18300, Energy: 126.39379603696304
# Iteration 18400, Energy: 126.35115500758778
# Iteration 18500, Energy: 126.30892955456777
# Iteration 18600, Energy: 126.26546080913424
# Iteration 18700, Energy: 126.22293607719125
# Iteration 18800, Energy: 126.18435788851016
# Iteration 18900, Energy: 126.14163297671314
# Iteration 19000, Energy: 126.1000577058918
# Iteration 19100, Energy: 126.05899399458961
# Iteration 19200, Energy: 126.017255803094
# Iteration 19300, Energy: 125.97761460680094
# Iteration 19400, Energy: 125.93661046024108
# Iteration 19500, Energy: 125.8926999946985
# Iteration 19600, Energy: 125.85010343739279
# Iteration 19700, Energy: 125.81036830493
# Iteration 19800, Energy: 125.77031590366286
# Iteration 19900, Energy: 125.72895499885227
# Iteration 20000, Energy: 125.69004259593693
# Iteration 20100, Energy: 125.64652456533437
# Iteration 20200, Energy: 125.6064724113093
# Iteration 20300, Energy: 125.56909287961074
# Iteration 20400, Energy: 125.53073806314224
# Iteration 20500, Energy: 125.48979938445649
# Iteration 20600, Energy: 125.45048195775836
# Iteration 20700, Energy: 125.41086252601187
# Iteration 20800, Energy: 125.36934465219356
# Iteration 20900, Energy: 125.33136177509984
# Iteration 21000, Energy: 125.2914209955092
# Iteration 21100, Energy: 125.25019124806617
# Iteration 21200, Energy: 125.20983311385463
# Iteration 21300, Energy: 125.1709841422688
# Iteration 21400, Energy: 125.13247679383022
# Iteration 21500, Energy: 125.08966707399337
# Iteration 21600, Energy: 125.05352002967354
# Iteration 21700, Energy: 125.0174366375998
# Iteration 21800, Energy: 124.98027170502006
# Iteration 21900, Energy: 124.94074119997549
# Iteration 22000, Energy: 124.90581952870295
# Iteration 22100, Energy: 124.86405570665009
# Iteration 22200, Energy: 124.82717679034214
# Iteration 22300, Energy: 124.78737261376948
# Iteration 22400, Energy: 124.74839062328779
# Iteration 22500, Energy: 124.70999745865957
# Iteration 22600, Energy: 124.67561811836268
# Iteration 22700, Energy: 124.6357296864472
# Iteration 22800, Energy: 124.59598659409274
# Iteration 22900, Energy: 124.5580401380138
# Iteration 23000, Energy: 124.51824485821867
# Iteration 23100, Energy: 124.47420449439528
# Iteration 23200, Energy: 124.43599024647685
# Iteration 23300, Energy: 124.4009069566772
# Iteration 23400, Energy: 124.36329068101207
# Iteration 23500, Energy: 124.3196042675435
# Iteration 23600, Energy: 124.28190619956581
# Iteration 23700, Energy: 124.23820592437416
# Iteration 23800, Energy: 124.19832295336823
# Iteration 23900, Energy: 124.15827325250991
# Iteration 24000, Energy: 124.11810750357206
# Iteration 24100, Energy: 124.07940830215203
# Iteration 24200, Energy: 124.04212771162071
# Iteration 24300, Energy: 123.99693533077777
# Iteration 24400, Energy: 123.9593746382919
# Iteration 24500, Energy: 123.90910605460978
# Iteration 24600, Energy: 123.87172515875982
# Iteration 24700, Energy: 123.83632514116022
# Iteration 24800, Energy: 123.79405317058256
# Iteration 24900, Energy: 123.75207835096334
# Iteration 25000, Energy: 123.71457974313945
# Iteration 25100, Energy: 123.67866848442384
# Iteration 25200, Energy: 123.63734295083304
# Iteration 25300, Energy: 123.59507376393411
# Iteration 25400, Energy: 123.55250218845741
# Iteration 25500, Energy: 123.51381908722749
# Iteration 25600, Energy: 123.48116444438278
# Iteration 25700, Energy: 123.44160322450196
# Iteration 25800, Energy: 123.40095684507165
# Iteration 25900, Energy: 123.36188530855475
# Iteration 26000, Energy: 123.32093389377275
# Iteration 26100, Energy: 123.27956760977443
# Iteration 26200, Energy: 123.24062825432254
# Iteration 26300, Energy: 123.19718174966424
# Iteration 26400, Energy: 123.15839458666858
# Iteration 26500, Energy: 123.12102956433932
# Iteration 26600, Energy: 123.07996396207419
# Iteration 26700, Energy: 123.03856378249067
# Iteration 26800, Energy: 123.0027749390485
# Iteration 26900, Energy: 122.95785297776806
# Iteration 27000, Energy: 122.91382012085178
# Iteration 27100, Energy: 122.8774700941994
# Iteration 27200, Energy: 122.8387272146436
# Iteration 27300, Energy: 122.80001813929813
# Iteration 27400, Energy: 122.76511950252497
# Iteration 27500, Energy: 122.7252785959076
# Iteration 27600, Energy: 122.68908971629543
# Iteration 27700, Energy: 122.64908604683039
# Iteration 27800, Energy: 122.61563944148433
# Iteration 27900, Energy: 122.58405628286434
# Iteration 28000, Energy: 122.53992888656983
# Iteration 28100, Energy: 122.50524083483141
# Iteration 28200, Energy: 122.46995220074466
# Iteration 28300, Energy: 122.43296944658204
# Iteration 28400, Energy: 122.39538913176004
# Iteration 28500, Energy: 122.35581976307043
# Iteration 28600, Energy: 122.32124109621165
# Iteration 28700, Energy: 122.28308435643544
# Iteration 28800, Energy: 122.23683181117434
# Iteration 28900, Energy: 122.20009197851775
# Iteration 29000, Energy: 122.16108193115168
# Iteration 29100, Energy: 122.12640129819508
# Iteration 29200, Energy: 122.08423413553685
# Iteration 29300, Energy: 122.05289365997804
# Iteration 29400, Energy: 122.01386673846065
# Iteration 29500, Energy: 121.98186693948223
# Iteration 29600, Energy: 121.94821272594818
# Iteration 29700, Energy: 121.91088310181496
# Iteration 29800, Energy: 121.87007358237827
# Iteration 29900, Energy: 121.8316109999795
# Iteration 30000, Energy: 121.78789787161396
# Iteration 30100, Energy: 121.75112869758657
# Iteration 30200, Energy: 121.71515973863308
# Iteration 30300, Energy: 121.67417930340322
# Iteration 30400, Energy: 121.63766203274423
# Iteration 30500, Energy: 121.59990872839205
# Iteration 30600, Energy: 121.56055108344589
# Iteration 30700, Energy: 121.52417759824134
# Iteration 30800, Energy: 121.49018270695913
# Iteration 30900, Energy: 121.45671525241673
# Iteration 31000, Energy: 121.4212973641316
# Iteration 31100, Energy: 121.38997853130539
# Iteration 31200, Energy: 121.3552311400273
# Iteration 31300, Energy: 121.32251504678305
# Iteration 31400, Energy: 121.28989853935433
# Iteration 31500, Energy: 121.25894948755652
# Iteration 31600, Energy: 121.22298627988025
# Iteration 31700, Energy: 121.18230483086691
# Iteration 31800, Energy: 121.14981751560346
# Iteration 31900, Energy: 121.11511538660811
# Iteration 32000, Energy: 121.08520354760715
# Iteration 32100, Energy: 121.05158597366722
# Iteration 32200, Energy: 121.02172471339006
# Iteration 32300, Energy: 120.9854403819401
# Iteration 32400, Energy: 120.95662365105444
# Iteration 32500, Energy: 120.92690938082478
# Iteration 32600, Energy: 120.89446787842891
# Iteration 32700, Energy: 120.85749467648421
# Iteration 32800, Energy: 120.82168538671282
# Iteration 32900, Energy: 120.78879588909639
# Iteration 33000, Energy: 120.75439639965259
# Iteration 33100, Energy: 120.72598669920438
# Iteration 33200, Energy: 120.70104431455688
# Iteration 33300, Energy: 120.66669479331631
# Iteration 33400, Energy: 120.63443920114918
# Iteration 33500, Energy: 120.59874742005907
# Iteration 33600, Energy: 120.57525127777132
# Iteration 33700, Energy: 120.5469781404786
# Iteration 33800, Energy: 120.51313039412591
# Iteration 33900, Energy: 120.48417373165854
# Iteration 34000, Energy: 120.45637579654642
# Iteration 34100, Energy: 120.42334061550987
# Iteration 34200, Energy: 120.38878769802675
# Iteration 34300, Energy: 120.35953302771631
# Iteration 34400, Energy: 120.32386219750796
# Iteration 34500, Energy: 120.29692270055445
# Iteration 34600, Energy: 120.26259519291473
# Iteration 34700, Energy: 120.23907115027671
# Iteration 34800, Energy: 120.20487802947589
# Iteration 34900, Energy: 120.1649005342325
# Iteration 35000, Energy: 120.13528220778953
# Iteration 35100, Energy: 120.10583210453792
# Iteration 35200, Energy: 120.07044662917932
# Iteration 35300, Energy: 120.03971369826874
# Iteration 35400, Energy: 120.00139533158364
# Iteration 35500, Energy: 119.96899854240142
# Iteration 35600, Energy: 119.9376692461511
# Iteration 35700, Energy: 119.90317416119568
# Iteration 35800, Energy: 119.87041956879209
# Iteration 35900, Energy: 119.8415671083345
# Iteration 36000, Energy: 119.81041514844316
# Iteration 36100, Energy: 119.78475671070451
# Iteration 36200, Energy: 119.74664016304449
# Iteration 36300, Energy: 119.71269565815558
# Iteration 36400, Energy: 119.6837006675562
# Iteration 36500, Energy: 119.65002033379348
# Iteration 36600, Energy: 119.61600164203458
# Iteration 36700, Energy: 119.5881899456464
# Iteration 36800, Energy: 119.55777654905117
# Iteration 36900, Energy: 119.52337075059216
# Iteration 37000, Energy: 119.48876671977044
# Iteration 37100, Energy: 119.46202199228867
# Iteration 37200, Energy: 119.42865241425454
# Iteration 37300, Energy: 119.4032542910432
# Iteration 37400, Energy: 119.37159862003627
# Iteration 37500, Energy: 119.33261517329072
# Iteration 37600, Energy: 119.2972035816786
# Iteration 37700, Energy: 119.26708929067411
# Iteration 37800, Energy: 119.24179704161773
# Iteration 37900, Energy: 119.21850871371002
# Iteration 38000, Energy: 119.18989820246216
# Iteration 38100, Energy: 119.15744200380931
# Iteration 38200, Energy: 119.12925222083639
# Iteration 38300, Energy: 119.1039783712386
# Iteration 38400, Energy: 119.07791077586045
# Iteration 38500, Energy: 119.05438152057637
# Iteration 38600, Energy: 119.01821522610064
# Iteration 38700, Energy: 118.9896635337131
# Iteration 38800, Energy: 118.96966324429788
# Iteration 38900, Energy: 118.94976291420451
# Iteration 39000, Energy: 118.92376231778131
# Iteration 39100, Energy: 118.89980392904343
# Iteration 39200, Energy: 118.87706695626383
# Iteration 39300, Energy: 118.85386847161648
# Iteration 39400, Energy: 118.82826713298405
# Iteration 39500, Energy: 118.80522694926492
# Iteration 39600, Energy: 118.78257225352331
# Iteration 39700, Energy: 118.76994483223379
# Iteration 39800, Energy: 118.74943366702124
# Iteration 39900, Energy: 118.72675750584193
# Iteration 40000, Energy: 118.70764317244068
# Iteration 40100, Energy: 118.6894383407139
# Iteration 40200, Energy: 118.67581783067966
# Iteration 40300, Energy: 118.6619795790868
# Iteration 40400, Energy: 118.64751850212477
# Iteration 40500, Energy: 118.63290116140621
# Iteration 40600, Energy: 118.61901720658807
# Iteration 40700, Energy: 118.60513193387895
# Iteration 40800, Energy: 118.59007886181392
# Iteration 40900, Energy: 118.57859723808487
# Iteration 41000, Energy: 118.56472887796198
# Iteration 41100, Energy: 118.5537495361996
# Iteration 41200, Energy: 118.5426538900107
# Iteration 41300, Energy: 118.53204474946463
# Iteration 41400, Energy: 118.52127508379553
# Iteration 41500, Energy: 118.51164241610158
# Iteration 41600, Energy: 118.5014146351132
# Iteration 41700, Energy: 118.4916097429177
# Iteration 41800, Energy: 118.48247151044329
# Iteration 41900, Energy: 118.47131700308086
# Iteration 42000, Energy: 118.46226088016621
# Iteration 42100, Energy: 118.45365096701757
# Iteration 42200, Energy: 118.44540919241282
# Iteration 42300, Energy: 118.43672785407131
# Iteration 42400, Energy: 118.42759356350165
# Iteration 42500, Energy: 118.42092778056225
# Iteration 42600, Energy: 118.41377243573591
# Iteration 42700, Energy: 118.40736116868067
# Iteration 42800, Energy: 118.40063875931672
# Iteration 42900, Energy: 118.39373591591661
# Iteration 43000, Energy: 118.38649381289818
# Iteration 43100, Energy: 118.3797309428589
# Iteration 43200, Energy: 118.37295842667572
# Iteration 43300, Energy: 118.36603459682959
# Iteration 43400, Energy: 118.36016593133535
# Iteration 43500, Energy: 118.35382713137967
# Iteration 43600, Energy: 118.34823230416731
# Iteration 43700, Energy: 118.34192455572864
# Iteration 43800, Energy: 118.33538580953169
# Iteration 43900, Energy: 118.32986972612156
# Iteration 44000, Energy: 118.32422454189317
# Iteration 44100, Energy: 118.31855255443786
# Iteration 44200, Energy: 118.31270317686091
# Iteration 44300, Energy: 118.30679168242766
# Iteration 44400, Energy: 118.30068962115828
# Iteration 44500, Energy: 118.29535338748146
# Iteration 44600, Energy: 118.28985239122927
# Iteration 44700, Energy: 118.2840738974095
# Iteration 44800, Energy: 118.27803506101584
# Iteration 44900, Energy: 118.27308932361856
# Iteration 45000, Energy: 118.2669293850767
# Iteration 45100, Energy: 118.26101098310498
# Iteration 45200, Energy: 118.25620661050361
# Iteration 45300, Energy: 118.25057902897969
# Iteration 45400, Energy: 118.24480033787371
# Iteration 45500, Energy: 118.23940109968503
# Iteration 45600, Energy: 118.23353462629811
# Iteration 45700, Energy: 118.22782335695375
# Iteration 45800, Energy: 118.22271527730341
# Iteration 45900, Energy: 118.21656875763317
# Iteration 46000, Energy: 118.21134595198747
# Iteration 46100, Energy: 118.20562498323395
# Iteration 46200, Energy: 118.20125298427898
# Iteration 46300, Energy: 118.19546528586902
# Iteration 46400, Energy: 118.19021428084821
# Iteration 46500, Energy: 118.18488897483012
# Iteration 46600, Energy: 118.179114020646
# Iteration 46700, Energy: 118.17386317077379
# Iteration 46800, Energy: 118.16926192036642
# Iteration 46900, Energy: 118.16478153327276
# Iteration 47000, Energy: 118.1600156867659
# Iteration 47100, Energy: 118.15459022017458
# Iteration 47200, Energy: 118.14981599418057
# Iteration 47300, Energy: 118.14556042240251
# Iteration 47400, Energy: 118.1394401267269
# Iteration 47500, Energy: 118.13459894907365
# Iteration 47600, Energy: 118.1300071458935
# Iteration 47700, Energy: 118.12528471314309
# Iteration 47800, Energy: 118.11961871593917
# Iteration 47900, Energy: 118.11417792450217
# Iteration 48000, Energy: 118.10954689221704
# Iteration 48100, Energy: 118.10398005999689
# Iteration 48200, Energy: 118.09876365612404
# Iteration 48300, Energy: 118.09434689171442
# Iteration 48400, Energy: 118.08953077321088
# Iteration 48500, Energy: 118.0842721997907
# Iteration 48600, Energy: 118.07865071127664
# Iteration 48700, Energy: 118.07375061342864
# Iteration 48800, Energy: 118.06857714682728
# Iteration 48900, Energy: 118.06297234774779
# Iteration 49000, Energy: 118.05817973461609
# Iteration 49100, Energy: 118.05326382607817
# Iteration 49200, Energy: 118.04866206717807
# Iteration 49300, Energy: 118.04320053123183
# Iteration 49400, Energy: 118.03865584424776
# Iteration 49500, Energy: 118.03423997116805
# Iteration 49600, Energy: 118.02970750982193
# Iteration 49700, Energy: 118.02549454518363
# Iteration 49800, Energy: 118.02057131611544
# Iteration 49900, Energy: 118.01603930717077
# Optimized Theta Values: [12.90017501  0.510319   -0.84935945 ... 10.77206858 -7.88871153
#  -5.31235589]

# %%
# 可视化优化后的theta
theta_function = Function(T)
theta_function.vector()[:] = optimized_theta

plot_theta_vector(theta_function, mesh=mymesh, scale=12, width=0.0018, title="Vector field(SGD)")
save_data.save_vector_field_to_txt(mymesh, theta_function, filename="output/theta_vector(SGD).txt")

# 绘制能量随迭代次数的变化图
plt.figure()
plt.plot(energy_history)
plt.title("Convergence of Energy(SGD)")
plt.xlabel("Iteration")
plt.ylabel("Energy")
plt.grid(True)
plt.show()
# Out:
# File 'output/theta_vector(SGD).txt' created successfully.

# %%
# 对比Adam和SGD优化器的收敛情况

# 使用之前的数据，不重新创建优化器

# 绘制对比图
plt.figure(figsize=(12, 6))
plt.plot(energy_history, label='Adam')  # 假设energy_history是Adam优化器的结果
plt.plot(energy_history_sgd, label='SGD')  # 假设energy_history_sgd是SGD优化器的结果
plt.title("收敛对比：Adam vs SGD")
plt.xlabel("迭代次数")
plt.ylabel("能量")
plt.legend()
plt.grid(True)
plt.show()

# 输出最终能量值
print(f"Adam最终能量: {energy_history[-1]}")
print(f"SGD最终能量: {energy_history_sgd[-1]}")

# 计算收敛速度（以达到最终能量的95%为标准）
final_energy_adam = energy_history[-1]
final_energy_sgd = energy_history_sgd[-1]

convergence_threshold_adam = final_energy_adam * 1.05
convergence_threshold_sgd = final_energy_sgd * 1.05

convergence_iteration_adam = next(i for i, e in enumerate(energy_history) if e <= convergence_threshold_adam)
convergence_iteration_sgd = next(i for i, e in enumerate(energy_history_sgd) if e <= convergence_threshold_sgd)

print(f"Adam收敛迭代次数: {convergence_iteration_adam}")
print(f"SGD收敛迭代次数: {convergence_iteration_sgd}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 8
#       6 plt.figure(figsize=(12, 6))
#       7 plt.plot(energy_history, label='Adam')  # 假设energy_history是Adam优化器的结果
# ----> 8 plt.plot(energy_history_sgd, label='SGD')  # 假设energy_history_sgd是SGD优化器的结果
#       9 plt.title("收敛对比：Adam vs SGD")
#      10 plt.xlabel("迭代次数")
#
# NameError: name 'energy_history_sgd' is not defined
